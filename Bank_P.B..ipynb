# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from sklearn.manifold import TSNE
from pandas.tools.plotting import andrews_curves
import os
from pandas.tools.plotting import parallel_coordinates
from pandas.tools.plotting import radviz
import scipy
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#Modelling
from sklearn.linear_model import LinearRegression,LassoCV, Ridge, LassoLarsCV,ElasticNetCV
from sklearn.model_selection import GridSearchCV, cross_val_score, learning_curve
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler, Normalizer, RobustScaler
import xgboost as xgb
#import lightgbm as lgb
import warnings
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning:
#
# This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.

# %%
os.chdir('/home/py/data/BANKING/')

# %%
os.listdir(".")
# Out:
# ['bank_imp.csv', 'bank_final.csv']

# %%
df = pd.read_csv('bank_final.csv')

# %%
df.head(5)
# Out:
#    YEAR    DIV    ROE    ROC    NPM    DEP  Beta   P.B   P.E  EBVIDTA
# 0  1865  17.86  20.68  14.24  12.71  439.7  1.11  0.88  5.42     0.01
# 1  1865  16.04  24.57  14.52  13.34  479.6  1.08  0.79  3.51     0.01
# 2  1865  20.37  21.40  11.54  11.31  580.2  1.04  1.08  5.48     0.30
# 3  1865  20.08  22.01  11.26  11.41  619.4  1.06  1.44  7.72     0.67
# 4  1865  16.07  22.99  11.57  10.94  692.6  1.06  0.97  5.40     0.51

# %%
#del df['Company.Name']
del df['P.E']
del df['EBVIDTA']

# %%
df.shape
# Out:
# (367, 8)

# %% [markdown]
# # Feature Engineering

# %%
df["YEAR"] = df["YEAR"].astype("category")

# %%
# put ages in categories and add as columns to DataFrame
age_bins = [0, 1960, 1970, 1980, 1990,2000,2017]
age_labels = ["1", "2", "3", "4","5","6"]
df['YEAR'] = pd.cut(df['YEAR'], age_bins, labels=age_labels,right=True, include_lowest=True)

# %%
def multiplot(data,features,plottype,nrows,ncols,figsize,y=None,colorize=False):
    """ This function draw a multi plot for 3 types of plots ["regplot","distplot","coutplot"]"""
    n = 0
    plt.figure(1)
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    
    if colorize:
        colors = sns.color_palette(n_colors=(nrows*ncols))
    else :
        colors = [None]*(nrows*ncols)
        
    for row in range(ncols):
        for col in range(nrows):
            
            if plottype == 'regplot':
                if y == None:
                    raise ValueError('y value is needed with regplot type')
                
                sns.regplot(data = data, x = features[n], y = y ,ax=axes[row,col], color = colors[n])
                correlation = np.corrcoef(data[features[n]],data[y])[0,1]
                axes[row,col].set_title("Correlation {:.2f}".format(correlation))
            
            elif plottype == 'distplot':
                sns.distplot(a = data[features[n]],ax = axes[row,col],color=colors[n])
                skewness = data[features[n]].skew()
                axes[row,col].legend(["Skew : {:.2f}".format(skewness)])
            
            elif plottype in ['countplot']:
                g = sns.countplot(x = data[features[n]], y = y, ax = axes[row,col],color = colors[n])
                g = plt.setp(g.get_xticklabels(), rotation=45)
                
            n += 1
    plt.tight_layout()
    plt.show()
    plt.gcf().clear()

# %%
feats = ['ROE', 'ROC', 'NPM', 'DIV', 'DEP','Beta']

multiplot(data = df,features = feats,plottype = "regplot",nrows = 2, ncols = 2,
          figsize = (10,6),y = 'P.B', colorize = True)

# %%
skewed_features = ['ROE', 'ROC', 'NPM', 'DIV', 'DEP','Beta']
multiplot(data = df,features = skewed_features,plottype = "distplot",
          nrows = 2, ncols = 2, figsize = (11,9), colorize = True)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
for feature in skewed_features:
    df[feature] = np.log1p(df[feature])
multiplot(data = df,features = skewed_features,plottype = "distplot",
          nrows = 2, ncols = 2, figsize = (11,9), colorize = True)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
plt.figure(1)
fig, axes = plt.subplots(1,2,figsize=(15,7))

sns.distplot(df['P.B'],ax = axes[0])
sns.distplot(np.log1p(df['P.B']),ax = axes[1],color="g")

axes[0].legend(["Skew : {:.2f}".format(df['P.B'].skew())])
axes[1].legend(["Skew : {:.2f}".format(np.log1p(df['P.B']).skew())])

plt.tight_layout()
plt.show()
plt.gcf().clear()
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
t = df.iloc[:,1:7]

# %%
z= df.filter(['YEAR','P.B'], axis=1)

# %%
list_ib = t.columns.values

for i in list_ib:
    for j in list_ib:
        if i == j:
            break
        else:
            new = t[i] * t[j]
            t['new_' + str(i) + '_' + str(j)] = new # Add new column which is the result of multiplying columns i and j together

# %%
df = pd.concat([t, z], axis = 1)

# %%
# Convert year to category
df['Age_1'] = df['YEAR'].map(lambda s: 1 if s == '1' else 0)
df['Age_2'] = df['YEAR'].map(lambda s: 1 if s == '2' else 0)
df['Age_3'] = df['YEAR'].map(lambda s: 1 if s == '3' else 0)
df['Age_4'] = df['YEAR'].map(lambda s: 1 if s == '4' else 0)
df['Age_5'] = df['YEAR'].map(lambda s: 1 if s == '5' else 0)
df['Age_6'] = df['YEAR'].map(lambda s: 1 if s == '6'  else 0)

# %%
df.tail(5)
# Out:
#           DIV       ROE       ROC       NPM       DEP      Beta  new_ROE_DIV  \
# 362  2.737609  3.182212  2.037317  2.684440  6.014204  0.900161     8.711652
# 363  2.867899  3.248823  1.902108  2.676215  6.250168  0.936093     9.317296
# 364  2.938103  3.259250  1.927164  2.695978  6.449996  0.966984     9.576012
# 365  2.983660  3.105931  1.953028  2.746630  6.746882  1.043804     9.267041
# 366  2.866193  3.040706  1.958685  2.809403  7.008957  0.996949     8.715249
#
#      new_ROC_DIV  new_ROC_ROE  new_NPM_DIV  ...    new_Beta_NPM  new_Beta_DEP  \
# 362     5.577376     6.483173     7.348948  ...        2.416429      5.413754
# 363     5.455052     6.179610     7.675115  ...        2.505188      5.850741
# 364     5.662207     6.281109     7.921060  ...        2.606967      6.237042
# 365     5.827170     6.065969     8.195008  ...        2.866943      7.042423
# 366     5.613970     5.955786     8.052290  ...        2.800830      6.987570
#
#      YEAR   P.B  Age_1  Age_2  Age_3  Age_4  Age_5  Age_6
# 362     6  2.87      0      0      0      0      0      1
# 363     6  2.73      0      0      0      0      0      1
# 364     6  2.09      0      0      0      0      0      1
# 365     6  2.92      0      0      0      0      0      1
# 366     6  2.64      0      0      0      0      0      1
#
# [5 rows x 29 columns]

# %% [markdown]
# # Explanotary Data Analysis

# %%
andrews_curves(df, 'YEAR')
plt.show()

# %%
parallel_coordinates(df, 'YEAR')

# %%
radviz(df, 'YEAR')

# %%
tsne = TSNE(
    n_components=3,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    n_iter=300,
    verbose=2,
    angle=0.5
)

# %%
tsne_results = tsne.fit_transform(df.iloc[:, 1:], df.iloc[:, 0:])
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 367 / 367
# [t-SNE] Mean sigma: 3.045356
# [t-SNE] Iteration 25: error = 0.8531845, gradient norm = 0.0026123
# [t-SNE] Iteration 50: error = 0.6378946, gradient norm = 0.0012834
# [t-SNE] Iteration 75: error = 0.3453436, gradient norm = 0.0008467
# [t-SNE] Iteration 75: gradient norm 0.000847. Finished.
# [t-SNE] KL divergence after 75 iterations with early exaggeration: 0.345344
# [t-SNE] Iteration 100: error = 0.1772883, gradient norm = 0.0006628
# [t-SNE] Iteration 100: gradient norm 0.000663. Finished.
# [t-SNE] Error after 100 iterations: 0.345344

# %%
trace1 = go.Scatter3d(
    x=tsne_results[:,0],
    y=tsne_results[:,1],
    z=tsne_results[:,2],
    mode='markers',
    marker=dict(
        sizemode='diameter',
        color = df['P.B'].values,
        colorscale = 'Portland',
        colorbar = dict(title = 'YEAR'),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.75
    )
)

data=[trace1]
layout=dict(height=800, width=800, title='Data')
fig=dict(data=data, layout=layout)
py.iplot(fig, filename='3DBubble')
# Out:
# <div id="220f8666-dea3-4424-8450-27d6ba15f2cb" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("220f8666-dea3-4424-8450-27d6ba15f2cb", [{"type": "scatter3d", "x": [0.46806239289352297, -8.841592526596537, 0.01478324768111499, -9.385422470796222, 2.439061173302499, 5.304460113915506, 14.422017562334066, -19.066709225254268, -0.7263068581414589, -1.3673779690572296, -1.2657252140811164, 1.8233104363561243, -21.22443388409478, -17.907355033908015, -18.4849511243675, 7.976843231940983, 5.129802640390232, 2.7244186602643823, 0.6554528901377523, -2.647371855266691, -1.7079054601184582, -0.09454356179181927, 1.4993021938922355, -2.0311516622092163, 5.6773526093122335, -11.301165185227646, -5.450149928240304, -7.210741084991912, -6.2727608018353616, -3.3945532948243735, 23.16484247435351, -8.539385670751528, 1.1115137553294083, -1.8165646969535962, -0.8194828281527249, -1.3557409293634557, 2.6000740776450963, 7.295991078403497, 7.191434302072156, -4.951901737352517, 4.7527460385947915, -11.467489171180572, 8.680843255975958, 10.858008672570227, 1.752926207508597, 6.3122170152958486, 4.328192963413021, 2.1818630680607622, 4.322174843992422, 7.691736544585239, -15.49834993701067, -21.116064464127028, 7.450775083421894, -14.896820931034814, -12.083345206930018, -9.54957155745471, -20.182319190051796, -5.276898437801312, 16.09268127490753, 22.889904272645932, -16.877706431793136, -14.765359127261176, 5.926401941584624, -6.842544940711791, -7.725841366565327, -5.078469490988934, -5.7169826662900896, -2.74200593836974, 2.033278092338237, 16.28117035199112, -13.315682352873027, -2.436469321461394, -19.01882603794572, 18.871482117425753, 15.719841712201722, -8.916883404581526, 4.907622690446242, -15.314150938747831, -15.362984541167624, -6.151223216448421, -8.511408215392716, 2.6579695196929913, -1.710969652229925, 11.552280613225207, 0.20929044783677375, -0.5304731464098611, -3.3507835457103496, -0.6201536990233512, 0.1998604259018594, -3.0232085610399215, 1.3938648146530037, 11.656981683461682, -1.7801926430156851, -0.5573279781893504, -0.7981366052325594, 3.680581179640703, -20.903904163904407, -16.050317547109646, 13.086131179540418, -0.6187741708080996, -19.589467785319012, -19.49562009053037, 10.895548633576828, 17.489720006969005, 17.575362971018098, 8.708435576978589, 13.551607089493146, 11.68291773338663, 8.781682357128549, 5.468402627627972, 7.747521968420931, -19.384780671859705, -14.642624077639704, 5.740006927893597, 0.17152545947130624, -16.164834102819697, 2.1115193435671333, -18.42171021720787, -14.088643192687142, -6.12703138388674, 15.141249125440194, -14.15631438143592, -6.524794730743672, -3.392071412197966, -4.731317819781847, -6.3792624468427706, -9.487728934209173, -12.416989967191496, -10.942215596892016, -7.071785821234113, -10.152374890064154, -8.441962488251972, 7.05420688994647, 6.151520467045538, 8.656663274976802, 6.480705933601621, 2.6374774030172423, 3.5780772919187163, 1.7348302077390092, -0.3571800371900521, 0.8131891164598558, 2.692533010588399, -14.489006329610335, -10.18575083882898, -14.736980279167481, -11.060242705108655, -5.659360699022771, 10.241879982669563, -8.519304769114594, -17.583462424271552, -20.921497116056845, 17.81683236809268, 4.8632733539571, 9.250522231784318, -16.621235116502003, 14.961825595614828, -20.21803938133444, -18.470597300227478, -17.128968155421955, 16.860694555571524, -1.3045051706361712, -10.515660234821626, -11.848050065593585, -4.809154958624676, -8.12310562130958, 11.33138096533497, 22.455469964994034, -13.188167544682562, -4.025075381120867, 12.966833652301297, -5.1471849591186, -9.569781251932845, 15.81559616627931, 16.19393334573128, 16.7231277953556, 19.61964355293239, 8.451610361918025, -7.840852898787923, -5.814653326438385, 3.93276050755941, -2.883822119624953, -2.58338931234380 ...

# %%
df.drop(labels=["YEAR"],axis = 1,inplace=True)

# %%
g = sns.jointplot(x = df['NPM'], y = df['P.B'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.jointplot(x = df['ROE'], y = df['P.B'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.jointplot(x = df['Beta'], y = df['P.B'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.jointplot(x = df['DEP'], y = df['P.B'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.distplot(df['P.B'],color="gray")
g = g.legend(['Skewness : {:.2f}'.format(df['P.B'].skew())],loc='best')
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different fearures')

# %% [markdown]
# # Transformation

# %%
df['P.B'] = np.log1p(df['P.B'])
Y = df['P.B']
df = df.drop(labels='P.B',axis = 1)

# %%
features = df.columns

# %%
# Normalize data 
#N = Normalizer()
N = RobustScaler()

N.fit(df)

df = N.transform(df)

# %%
train_len = len(df)

# %%
## Separate train dataset 
X_train = df[:train_len]

# %%
###### Train classifiers
Y_train = Y[:train_len]

# %%
lassocv = LassoCV(eps=1e-7) 
ridge = Ridge(alpha=0.05) 
lassolarscv = LassoLarsCV()
elasticnetcv = ElasticNetCV(eps=1e-7)

# %% [markdown]
# # 6.1.1 Cross validate models

# %%
# Regression linear models (Lasso, Ridge, Elasticnet)
def RMSE(estimator,X_train, Y_train, cv=5,n_jobs=4):
    cv_results = cross_val_score(estimator,X_train,Y_train,cv=cv,scoring="neg_mean_squared_error",n_jobs=n_jobs)
    return (np.sqrt(-cv_results)).mean()

# %%
RMSE(lassocv, X_train, Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# 0.2822278736881173

# %%
RMSE(ridge, X_train, Y_train)
# Out:
# 0.280758391235439

# %%
RMSE(lassolarscv, X_train, Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 41 iterations, alpha=4.207e-04, previous alpha=2.303e-05, with an active set of 22 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 41 iterations, alpha=4.207e-04, previous alpha=2.303e-05, with an active set of 22 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=1.328e-03, previous alpha=7.043e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 43 iterations, alpha=2.921e-03, previous alpha=2.137e-06, with an active set of 24 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=6.088e-04, previous alpha=8.983e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=3.902e-03, previous alpha=1.235e-05, with an active set of 21 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=6.320e-04, previous alpha=4.926e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=5.067e-03, previous alpha=2.570e-05, with an active set of 20 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=1.077e-03, previous alpha=4.785e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=8.898e-05, previous alpha=1.189e-05, with an active set of 20 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=1.632e-03, previous alpha=8.663e-05, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=2.725e-04, previous alpha=9.464e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=2.896e-04, previous alpha=3.524e-05, with an active set of 19 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=1.632e-03, previous alpha=8.663e-05, with an active set of 15 regressors.
# 0.27812513329485083

# %%
RMSE(elasticnetcv, X_train, Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# 0.28659441850364253

# %%
lassocv.fit(X_train,Y_train)
ridge.fit(X_train,Y_train)
lassolarscv.fit(X_train,Y_train)
elasticnetcv.fit(X_train,Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=3.076e-04, previous alpha=1.881e-05, with an active set of 24 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 41 iterations, alpha=1.020e-04, previous alpha=3.688e-05, with an active set of 22 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=1.296e-03, previous alpha=6.331e-05, with an active set of 16 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=1e-15, fit_intercept=True,
#        l1_ratio=0.5, max_iter=1000, n_alphas=100, n_jobs=1,
#        normalize=False, positive=False, precompute='auto',
#        random_state=None, selection='cyclic', tol=0.0001, verbose=0)

# %% [markdown]
# # Features coefficients

# %%
print("LassoCV regression has conserved %d features over %d"%(len(features[lassocv.coef_!=0]),X_train.shape[1]))
print("Ridge regression has conserved %d features over %d"%(len(features[ridge.coef_!=0]),X_train.shape[1]))
print("LassoLarsCV regression has conserved %d features over %d"%(len(features[lassolarscv.coef_!=0]) ,X_train.shape[1]))
print("ElasticNetCV regression has conserved %d features over %d"%(len(features[elasticnetcv.coef_!=0]),X_train.shape[1]))
# Out:
# LassoCV regression has conserved 17 features over 27
# Ridge regression has conserved 27 features over 27
# LassoLarsCV regression has conserved 14 features over 27
# ElasticNetCV regression has conserved 13 features over 27

# %%
nrows = ncols = 2
fig, axes = plt.subplots(nrows = nrows, ncols = ncols, sharex="all", figsize=(15,15))

names_regressors = [("LassoCV", lassocv),("Ridge",ridge),("LassolarsCV",lassolarscv),("ElasticNetCV",elasticnetcv)]

nregressors = 0
for row in range(nrows):
    for col in range(ncols):
        name = names_regressors[nregressors][0]
        regressor = names_regressors[nregressors][1]
        indices = np.argsort(regressor.coef_)[::-1][:40]
        g = sns.barplot(y=features[indices][:40],x = regressor.coef_[indices][:40] , orient='h',ax=axes[row][col])
        g.set_xlabel("Coefficient",fontsize=12)
        g.set_ylabel("Features",fontsize=12)
        g.tick_params(labelsize=9)
        g.set_title(name + " regression coefs")
        nregressors += 1
plt.tight_layout()
plt.show()
plt.gcf().clear()

# %%
Y_pred_lassocv = np.expm1(lassocv.predict(X_train))
Y_pred_lassolarscv = np.expm1(lassolarscv.predict(X_train))
Y_pred_elasticnetcv = np.expm1(elasticnetcv.predict(X_train))

# %% [markdown]
# # Tree based modeling

# %%
# XGBoost

#model_xgb = xgb.XGBRegressor(n_estimators=3000, max_depth=2, learning_rate=0.1)
model_xgb = xgb.XGBRegressor(colsample_bytree=0.2, gamma=0.0, 
                             learning_rate=0.05, max_depth=6, 
                             min_child_weight=1.5, n_estimators=7200,
                             reg_alpha=0.9, reg_lambda=0.6,
                             subsample=0.2,seed=42, silent=1)

RMSE(model_xgb,X_train,Y_train)
# Out:
# 0.26653621248144443

# %%
model_xgb.fit(X_train,Y_train)
Y_pred_xgb = np.expm1(model_xgb.predict(X_train))

# %%
# Gradient Boosting
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
RMSE(GBoost,X_train,Y_train)
# Out:
# 0.27549250707573852

# %%
GBoost.fit(X_train,Y_train)
Y_pred_GBoost = np.expm1(GBoost.predict(X_train))

# %%
# Light GBM
LightGB = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

RMSE(LightGB,X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-0f7d113db2b3> in <module>()
#       1 # Light GBM
# ----> 2 LightGB = lgb.LGBMRegressor(objective='regression',num_leaves=5,
#       3                               learning_rate=0.05, n_estimators=720,
#       4                               max_bin = 55, bagging_fraction = 0.8,
#       5                               bagging_freq = 5, feature_fraction = 0.2319,
#
# NameError: name 'lgb' is not defined

# %%
LightGB.fit(X_train,Y_train)
Y_pred_LightGB = np.expm1(LightGB.predict(X_train))

# %% [markdown]
# # Features importance

# %%
nrows = 1
ncols = 2
fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize=(15,15))

names_regressors = [("LightGBM",LightGB),("GBoosting",GBoost)]

nregressors = 0
for row in range(nrows):
    for col in range(ncols):
        name = names_regressors[nregressors][0]
        regressor = names_regressors[nregressors][1]
        indices = np.argsort(regressor.feature_importances_)[::-1][:40]
        g = sns.barplot(y=features[indices][:40],x = regressor.feature_importances_[indices][:40] , orient='h',ax=axes[nregressors])
        g.set_xlabel("Relative importance",fontsize=12)
        g.set_ylabel("Features",fontsize=12)
        g.tick_params(labelsize=9)
        g.set_title(name + " feature importance")
        nregressors += 1

plt.tight_layout()
plt.show()
plt.gcf().clear()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-b97d8b749754> in <module>()
#       3 fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize=(15,15))
#       4
# ----> 5 names_regressors = [("LightGBM",LightGB),("GBoosting",GBoost)]
#       6
#       7 nregressors = 0
#
# NameError: name 'LightGB' is not defined

# %% [markdown]
# # Learning Rate

# %%
def plot_learning_curves(estimators, titles, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 4)):
    """Generate a simple plot of the test and training learning curve"""
    nrows = len(estimators)//2
    ncols = (len(estimators)//nrows)+ (0 if len(estimators) % nrows == 0 else 1)
    plt.figure(1)
    fig, axes = plt.subplots(nrows, ncols, figsize=(10, 10))
    
    n = 0
    for col in range(ncols):
        for row in range(nrows):
            estimator = estimators[n]
            title = titles[n]
            axes[row,col].set_title(title)
            
            if ylim is not None:
                axes[row,col].set_ylim(*ylim)
            
            axes[row,col].set_xlabel("Training examples")
            axes[row,col].set_ylabel("Score")
            
            train_sizes, train_scores, test_scores = learning_curve(estimator,
                    X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes,
                    scoring="neg_mean_squared_error")
    
            train_scores = np.sqrt(-train_scores)
            test_scores = np.sqrt(-test_scores)
    
            train_scores_mean = np.mean(train_scores, axis=1)
            train_scores_std = np.std(train_scores, axis=1)
            test_scores_mean = np.mean(test_scores, axis=1)
            test_scores_std = np.std(test_scores, axis=1)
            axes[row,col].grid()
        
            axes[row,col].fill_between(train_sizes, train_scores_mean - train_scores_std,
                             train_scores_mean + train_scores_std, alpha=0.5,
                     color="r")
            axes[row,col].fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.5, color="g")
            axes[row,col].plot(train_sizes, train_scores_mean, 'o-', color="r",
                     label="Training score")
            axes[row,col].plot(train_sizes, test_scores_mean, 'o-', color="g",
                     label="Cross-validation score")
            axes[row,col].legend(loc="best")
            
            n += 1
    plt.tight_layout()
    plt.show()
    plt.gcf().clear()

    

estimators = [lassocv,lassolarscv,elasticnetcv,GBoost,model_xgb]
titles = ["LassoCV","LassoLarsCV","ElasticNet","Gradient Boosting","Xgboost"]

plot_learning_curves(estimators, titles, X_train, Y_train, cv=3 ,n_jobs=5)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=2.683e-03, previous alpha=4.472e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=1.785e-02, previous alpha=1.157e-04, with an active set of 10 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=8.750e-05, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 34 iterations, alpha=2.242e-03, previous alpha=7.155e-05, with an active set of 19 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=3.518e-05, with an active set of 19 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=2.205e-05, with an active set of 19 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=8.587e-03, previous alpha=2.494e-05, with an active set of 21 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=7.370e-03, previous alpha=2.119e-05, with an active set of 19 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=4.677e-05, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=8.360e-04, previous alpha=4.677e-05, with an active set of 10 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=7.011e-03, previous alpha=1.306e-05, with an active set of 11 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.970e-04, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.054e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=8.767e-03, previous alpha=5.626e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 29 iterations, alpha=8.138e-04, previous alpha=8.287e-05, with an active set of 16 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 44 iterations, alpha=2.494e-02, previous alpha=3.839e-05, with an active set of 13 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 47 iterations, alpha=6.195e-02, previous alpha=3.152e-05, with an active set of 10 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=9.317e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.788e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=6.302e-03, previous alpha=9.840e-05, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=6.454e-03, previous alpha=5.061e-05, with an active set of 20 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=5.421e-05, with an active set of 10 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=4.618e-05, with an active set of 10 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=4.649e-05, previous alpha=3.414e-05, with an active set of 12 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.691e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=3.883e-03, previous alpha=1.564e-03, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=1.662e-03, previous alpha=8.981e-05, with an active set of 16 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.029e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=9.317e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.788e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=2.168e-03, previous alpha=2.919e-04, with an active set of 12 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=4.677e-05, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=8.360e-04, previous alpha=4.677e-05, with an active set of 10 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=3.883e-03, previous alpha=1.564e-03, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=1.053e-05, previous alpha=6.694e-06, with an active set of 21 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=9.376e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=6.548e-04, previous alpha=1.121e-04, with an active set of 14 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.029e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.970e-04, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.054e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=1.102e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=9.023e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=1.876e-03, previous alpha=8.096e-05, with an active set of 16 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=2.168e-03, previous alpha=2.919e-04, with an active set of 12 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=6.513e-05, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 44 iterations, alpha=2.494e-02, previous alpha=3.839e-05, with an active set of 13 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=6.548e-04, previous alpha=1.121e-04, with an active set of 14 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 34 iterations, alpha=7.074e-03, previous alpha=5.816e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=5.421e-05, with an active set of 10 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=4.374e-03, previous alpha=1.865e-05, with an active set of 23 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=4.618e-05, with an active set of 10 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=9.023e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=4.649e-05, previous alpha=3.414e-05, with an active set of 12 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.691e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=3.391e-03, previous alpha=1.445e-05, with an active set of 21 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=8.810e-04, previous alpha=2.048e-05, with an active set of 22 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=1.003e-03, previous alpha=1.062e-04, with an active set of 13 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 34 iterations, alpha=9.824e-03, previous alpha=6.760e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=9.376e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=1.102e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=6.513e-05, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-85-4367456d7b1b> in <module>()
#      54 titles = ["LassoCV","LassoLarsCV","ElasticNet","Gradient Boosting","Xgboost"]
#      55
# ---> 56 plot_learning_curves(estimators, titles, X_train, Y_train, cv=3 ,n_jobs=5)
#
# <ipython-input-85-4367456d7b1b> in plot_learning_curves(estimators, titles, X, y, ylim, cv, n_jobs, train_sizes)
#      10     for col in range(ncols):
#      11         for row in range(nrows):
# ---> 12             estimator = estimators[n]
#      13             title = titles[n]
#      14             axes[row,col].set_title(title)
#
# IndexError: list index out of range
