# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from sklearn.manifold import TSNE
from pandas.tools.plotting import andrews_curves
import os
from pandas.tools.plotting import parallel_coordinates
from pandas.tools.plotting import radviz
import scipy
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#Modelling
from sklearn.linear_model import LinearRegression,LassoCV, Ridge, LassoLarsCV,ElasticNetCV
from sklearn.model_selection import GridSearchCV, cross_val_score, learning_curve
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler, Normalizer, RobustScaler
import xgboost as xgb
#import lightgbm as lgb
import warnings

# %%
os.chdir('/home/py/data/BANKING/')

# %%
os.listdir(".")
# Out:
# ['bank_imp.csv', 'bank_final.csv']

# %%
df = pd.read_csv('bank_final.csv')

# %%
df.head(5)
# Out:
#    YEAR    DIV    ROE    ROC    NPM    DEP  Beta   P.B   P.E  EBVIDTA
# 0  1865  17.86  20.68  14.24  12.71  439.7  1.11  0.88  5.42     0.01
# 1  1865  16.04  24.57  14.52  13.34  479.6  1.08  0.79  3.51     0.01
# 2  1865  20.37  21.40  11.54  11.31  580.2  1.04  1.08  5.48     0.30
# 3  1865  20.08  22.01  11.26  11.41  619.4  1.06  1.44  7.72     0.67
# 4  1865  16.07  22.99  11.57  10.94  692.6  1.06  0.97  5.40     0.51

# %%
#del df['Company.Name']
del df['P.E']
del df['P.B']

# %%
df.shape
# Out:
# (367, 8)

# %% [markdown]
# # Feature Engineering

# %%
df["YEAR"] = df["YEAR"].astype("category")

# %%
# put ages in categories and add as columns to DataFrame
age_bins = [0, 1960, 1970, 1980, 1990,2000,2017]
age_labels = ["1", "2", "3", "4","5","6"]
df['YEAR'] = pd.cut(df['YEAR'], age_bins, labels=age_labels,right=True, include_lowest=True)

# %%
def multiplot(data,features,plottype,nrows,ncols,figsize,y=None,colorize=False):
    """ This function draw a multi plot for 3 types of plots ["regplot","distplot","coutplot"]"""
    n = 0
    plt.figure(1)
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    
    if colorize:
        colors = sns.color_palette(n_colors=(nrows*ncols))
    else :
        colors = [None]*(nrows*ncols)
        
    for row in range(ncols):
        for col in range(nrows):
            
            if plottype == 'regplot':
                if y == None:
                    raise ValueError('y value is needed with regplot type')
                
                sns.regplot(data = data, x = features[n], y = y ,ax=axes[row,col], color = colors[n])
                correlation = np.corrcoef(data[features[n]],data[y])[0,1]
                axes[row,col].set_title("Correlation {:.2f}".format(correlation))
            
            elif plottype == 'distplot':
                sns.distplot(a = data[features[n]],ax = axes[row,col],color=colors[n])
                skewness = data[features[n]].skew()
                axes[row,col].legend(["Skew : {:.2f}".format(skewness)])
            
            elif plottype in ['countplot']:
                g = sns.countplot(x = data[features[n]], y = y, ax = axes[row,col],color = colors[n])
                g = plt.setp(g.get_xticklabels(), rotation=45)
                
            n += 1
    plt.tight_layout()
    plt.show()
    plt.gcf().clear()

# %%
feats = ['ROE', 'ROC', 'NPM', 'DIV', 'DEP','Beta']

multiplot(data = df,features = feats,plottype = "regplot",nrows = 2, ncols = 2,
          figsize = (10,6),y = 'EBVIDTA', colorize = True)

# %%
skewed_features = ['ROE', 'ROC', 'NPM', 'DIV', 'DEP','Beta']
multiplot(data = df,features = skewed_features,plottype = "distplot",
          nrows = 2, ncols = 2, figsize = (11,9), colorize = True)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
for feature in skewed_features:
    df[feature] = np.log1p(df[feature])
multiplot(data = df,features = skewed_features,plottype = "distplot",
          nrows = 2, ncols = 2, figsize = (11,9), colorize = True)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
plt.figure(1)
fig, axes = plt.subplots(1,2,figsize=(15,7))

sns.distplot(df['EBVIDTA'],ax = axes[0])
sns.distplot(np.log1p(df['EBVIDTA']),ax = axes[1],color="g")

axes[0].legend(["Skew : {:.2f}".format(df['EBVIDTA'].skew())])
axes[1].legend(["Skew : {:.2f}".format(np.log1p(df['EBVIDTA']).skew())])

plt.tight_layout()
plt.show()
plt.gcf().clear()
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
t = df.iloc[:,1:7]

# %%
z= df.filter(['YEAR','EBVIDTA'], axis=1)

# %%
list_ib = t.columns.values

for i in list_ib:
    for j in list_ib:
        if i == j:
            break
        else:
            new = t[i] * t[j]
            t['new_' + str(i) + '_' + str(j)] = new # Add new column which is the result of multiplying columns i and j together

# %%
df = pd.concat([t, z], axis = 1)

# %%
# Convert year to category
df['Age_1'] = df['YEAR'].map(lambda s: 1 if s == '1' else 0)
df['Age_2'] = df['YEAR'].map(lambda s: 1 if s == '2' else 0)
df['Age_3'] = df['YEAR'].map(lambda s: 1 if s == '3' else 0)
df['Age_4'] = df['YEAR'].map(lambda s: 1 if s == '4' else 0)
df['Age_5'] = df['YEAR'].map(lambda s: 1 if s == '5' else 0)
df['Age_6'] = df['YEAR'].map(lambda s: 1 if s == '6'  else 0)

# %%
df.tail(5)
# Out:
#           DIV       ROE       ROC       NPM       DEP      Beta  new_ROE_DIV  \
# 362  2.737609  3.182212  2.037317  2.684440  6.014204  0.900161     8.711652
# 363  2.867899  3.248823  1.902108  2.676215  6.250168  0.936093     9.317296
# 364  2.938103  3.259250  1.927164  2.695978  6.449996  0.966984     9.576012
# 365  2.983660  3.105931  1.953028  2.746630  6.746882  1.043804     9.267041
# 366  2.866193  3.040706  1.958685  2.809403  7.008957  0.996949     8.715249
#
#      new_ROC_DIV  new_ROC_ROE  new_NPM_DIV  ...    new_Beta_NPM  new_Beta_DEP  \
# 362     5.577376     6.483173     7.348948  ...        2.416429      5.413754
# 363     5.455052     6.179610     7.675115  ...        2.505188      5.850741
# 364     5.662207     6.281109     7.921060  ...        2.606967      6.237042
# 365     5.827170     6.065969     8.195008  ...        2.866943      7.042423
# 366     5.613970     5.955786     8.052290  ...        2.800830      6.987570
#
#      YEAR  EBVIDTA  Age_1  Age_2  Age_3  Age_4  Age_5  Age_6
# 362     6     3.97      0      0      0      0      0      1
# 363     6     4.14      0      0      0      0      0      1
# 364     6     3.03      0      0      0      0      0      1
# 365     6     4.57      0      0      0      0      0      1
# 366     6     4.46      0      0      0      0      0      1
#
# [5 rows x 29 columns]

# %% [markdown]
# # Explanotary Data Analysis

# %%
andrews_curves(df, 'YEAR')
plt.show()

# %%
parallel_coordinates(df, 'YEAR')

# %%
radviz(df, 'YEAR')

# %%
tsne = TSNE(
    n_components=3,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    n_iter=300,
    verbose=2,
    angle=0.5
)

# %%
tsne_results = tsne.fit_transform(df.iloc[:, 1:], df.iloc[:, 0:])
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 367 / 367
# [t-SNE] Mean sigma: 3.107417
# [t-SNE] Iteration 25: error = 0.8144262, gradient norm = 0.0050766
# [t-SNE] Iteration 50: error = 0.5748813, gradient norm = 0.0013580
# [t-SNE] Iteration 75: error = 0.3109714, gradient norm = 0.0007314
# [t-SNE] Iteration 75: gradient norm 0.000731. Finished.
# [t-SNE] KL divergence after 75 iterations with early exaggeration: 0.310971
# [t-SNE] Iteration 100: error = 0.1762385, gradient norm = 0.0006158
# [t-SNE] Iteration 100: gradient norm 0.000616. Finished.
# [t-SNE] Error after 100 iterations: 0.310971

# %%
trace1 = go.Scatter3d(
    x=tsne_results[:,0],
    y=tsne_results[:,1],
    z=tsne_results[:,2],
    mode='markers',
    marker=dict(
        sizemode='diameter',
        color = df['EBVIDTA'].values,
        colorscale = 'Portland',
        colorbar = dict(title = 'YEAR'),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.75
    )
)

data=[trace1]
layout=dict(height=800, width=800, title='Data')
fig=dict(data=data, layout=layout)
py.iplot(fig, filename='3DBubble')
# Out:
# <div id="e2a2d9fd-d124-4189-a187-b2d38ba424a3" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e2a2d9fd-d124-4189-a187-b2d38ba424a3", [{"type": "scatter3d", "x": [1.510133051635703, 0.03361738745351777, 0.5660542778756771, -13.176964725920655, 0.6976899496178998, 3.842466730370043, 14.081426116168974, -17.642892013527558, -1.8748607783628302, 2.102302512261987, 0.9926874443811206, 0.6807966828133685, -15.681963154853273, -14.518987345833686, -12.82268106593941, 9.394268895354294, 8.236115173654998, 5.78819506863614, -0.40752230035087295, 2.9186497499851147, 0.8272651288612097, -0.11957715050869475, 3.061484567758703, -0.3572730987241363, 11.281319568962248, -4.702236081983777, -4.953472160848319, -7.507476928643437, -4.488579108780155, 0.24726558171299695, -8.230276113768324, -7.95373948480789, -2.7329080646019985, 0.5235974521839418, 16.77162473866305, -4.421987470287694, 2.5017073032991464, -11.533472364799378, 6.816099672904047, -5.425390756179839, 16.672055942696204, -14.29084296536378, 4.711288700808333, 3.7986447114800965, 20.002093650950826, 19.167413846998937, -3.7398587798642233, 1.308892669309313, 0.5132206987723674, 14.340556207902244, -11.72455040013675, -13.564291902798876, -7.375340740668143, -11.566838098738192, -15.601905548360783, -10.517310866120976, -20.951436231715594, -9.712897696452142, 22.64515336817831, 8.10781635060456, -17.6285626194053, -17.504921109405263, -13.823511156200635, -2.1926227474638624, -7.977097212098771, -7.158185688253373, 1.3017858272786065, -2.8559780865331605, 3.195892165002358, -11.880079421602195, -10.28486126124874, -1.878852338143497, -14.792862496074331, 10.253966103539025, 8.77900452015628, -9.261936345388238, -4.875405536196148, -14.87279611571411, -15.991183177463402, -7.365257405634517, -6.863435784608777, 3.398932486041202, -2.3672261877763936, -1.6570495666877056, 0.7272619465043061, 2.0220702696399324, 1.3082713040241305, -0.13866179330659711, 2.828575744103269, -1.8274878558959695, 18.956674095687262, 14.826666005936154, 0.4230845497056666, 0.5275295287164342, -2.1810877915408238, 13.787686734735486, -22.388907237355227, -17.397076884036576, 14.719182077109215, 12.782559124384436, -18.221667958939886, -18.572092310089282, 10.716323008718128, 15.66396953441022, 17.766169106228627, 13.398515075820987, 15.078595421553496, 12.357677954700153, 11.278369728799785, 14.744769810382417, 8.415257229319508, -13.766957903403592, 4.083474372895132, 9.312035665796053, 0.10850285167173002, -17.519144348520168, 7.590628084349725, -16.412465582253393, -16.93109018098344, -7.71696288044594, 20.222010087859456, 1.3247872073325553, -27.379614302736588, 0.9468433685313007, 1.975434228590577, -3.16357302674748, 4.347017371465498, 5.030887418349708, -5.42361927170916, -2.601920556208386, -3.8666887308515565, -5.18074942665821, 6.774162948035067, -11.136063678207812, 10.374515396376799, 7.987841583542369, 5.440243657366868, 4.926786491840214, 2.5356145042820346, -0.5490181001868726, 19.503881837578543, 2.9130742759419745, -17.104111361573604, -13.019194949395997, -15.349563221068216, -14.262671477520678, -9.839627678213645, -8.447929577980961, -12.613135871402745, -18.225209415493048, -20.483194657703642, 7.898833318628124, 11.585807036522072, 9.959169532531808, -13.612371327149335, 0.9619804448022642, -21.341991106238083, -19.32519044000129, -15.86002708927828, 9.26351694970747, 1.1863787758668083, -15.257822321142397, -13.089419916302713, -9.249388332345202, -12.115633788971175, 18.31868779234647, -12.490207440433807, 2.0171143007178323, -11.451128519244397, 14.460451209569289, 7.710162809867625, -10.848640019940623, 11.309864683434704, 15.490249657894894, 16.385441508572093, 18.32716757332489, -13.870240698085514, 4.500027399472126, -7.43310106954279, 10.227655749780258, -4.934531972205702, -5.6881299543 ...

# %%
df.drop(labels=["YEAR"],axis = 1,inplace=True)

# %%
g = sns.jointplot(x = df['NPM'], y = df['EBVIDTA'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.jointplot(x = df['ROE'], y = df['EBVIDTA'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.jointplot(x = df['Beta'], y = df['EBVIDTA'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.jointplot(x = df['DEP'], y = df['EBVIDTA'],kind="reg")
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
g = sns.distplot(df['EBVIDTA'],color="gray")
g = g.legend(['Skewness : {:.2f}'.format(df['EBVIDTA'].skew())],loc='best')
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different fearures')

# %% [markdown]
# # Transformation

# %%
df['EBVIDTA'] = np.log1p(df['EBVIDTA'])
Y = df['EBVIDTA']
df = df.drop(labels='EBVIDTA',axis = 1)

# %%
features = df.columns

# %%
# Normalize data 
#N = Normalizer()
N = RobustScaler()

N.fit(df)

df = N.transform(df)

# %%
train_len = len(df)

# %%
## Separate train dataset 
X_train = df[:train_len]

# %%
###### Train classifiers
Y_train = Y[:train_len]

# %%
lassocv = LassoCV(eps=1e-7) 
ridge = Ridge(alpha=0.05) 
lassolarscv = LassoLarsCV()
elasticnetcv = ElasticNetCV(eps=1e-7)

# %% [markdown]
# # 6.1.1 Cross validate models

# %%
# Regression linear models (Lasso, Ridge, Elasticnet)
def RMSE(estimator,X_train, Y_train, cv=5,n_jobs=4):
    cv_results = cross_val_score(estimator,X_train,Y_train,cv=cv,scoring="neg_mean_squared_error",n_jobs=n_jobs)
    return (np.sqrt(-cv_results)).mean()

# %%
RMSE(lassocv, X_train, Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# 0.39607303579774095

# %%
RMSE(ridge, X_train, Y_train)
# Out:
# 0.40404228892597721

# %%
RMSE(lassolarscv, X_train, Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=3.220e-03, previous alpha=9.087e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=4.763e-03, previous alpha=3.916e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=4.763e-03, previous alpha=3.916e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=1.199e-02, previous alpha=6.139e-06, with an active set of 23 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=1.968e-03, previous alpha=9.656e-05, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=3.498e-04, previous alpha=9.557e-05, with an active set of 16 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=2.925e-04, previous alpha=8.417e-05, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=6.807e-04, previous alpha=6.335e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=1.878e-03, previous alpha=1.403e-04, with an active set of 14 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=1.381e-04, previous alpha=6.500e-05, with an active set of 16 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=2.919e-03, previous alpha=3.403e-05, with an active set of 22 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=5.046e-03, previous alpha=5.634e-05, with an active set of 16 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 40 iterations, alpha=2.445e-03, previous alpha=4.410e-06, with an active set of 23 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=5.046e-03, previous alpha=5.634e-05, with an active set of 16 regressors.
# 0.39745307920556944

# %%
RMSE(elasticnetcv, X_train, Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# 0.40163221820956319

# %%
lassocv.fit(X_train,Y_train)
ridge.fit(X_train,Y_train)
lassolarscv.fit(X_train,Y_train)
elasticnetcv.fit(X_train,Y_train)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 34 iterations, alpha=1.663e-03, previous alpha=3.002e-05, with an active set of 21 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=6.381e-03, previous alpha=5.440e-05, with an active set of 19 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=1e-07, fit_intercept=True,
#        l1_ratio=0.5, max_iter=1000, n_alphas=100, n_jobs=1,
#        normalize=False, positive=False, precompute='auto',
#        random_state=None, selection='cyclic', tol=0.0001, verbose=0)

# %% [markdown]
# # Features coefficients

# %%
print("LassoCV regression has conserved %d features over %d"%(len(features[lassocv.coef_!=0]),X_train.shape[1]))
print("Ridge regression has conserved %d features over %d"%(len(features[ridge.coef_!=0]),X_train.shape[1]))
print("LassoLarsCV regression has conserved %d features over %d"%(len(features[lassolarscv.coef_!=0]) ,X_train.shape[1]))
print("ElasticNetCV regression has conserved %d features over %d"%(len(features[elasticnetcv.coef_!=0]),X_train.shape[1]))
# Out:
# LassoCV regression has conserved 17 features over 27
# Ridge regression has conserved 27 features over 27
# LassoLarsCV regression has conserved 16 features over 27
# ElasticNetCV regression has conserved 15 features over 27

# %%
nrows = ncols = 2
fig, axes = plt.subplots(nrows = nrows, ncols = ncols, sharex="all", figsize=(15,15))

names_regressors = [("LassoCV", lassocv),("Ridge",ridge),("LassolarsCV",lassolarscv),("ElasticNetCV",elasticnetcv)]

nregressors = 0
for row in range(nrows):
    for col in range(ncols):
        name = names_regressors[nregressors][0]
        regressor = names_regressors[nregressors][1]
        indices = np.argsort(regressor.coef_)[::-1][:40]
        g = sns.barplot(y=features[indices][:40],x = regressor.coef_[indices][:40] , orient='h',ax=axes[row][col])
        g.set_xlabel("Coefficient",fontsize=12)
        g.set_ylabel("Features",fontsize=12)
        g.tick_params(labelsize=9)
        g.set_title(name + " regression coefs")
        nregressors += 1
plt.tight_layout()
plt.show()
plt.gcf().clear()

# %%
Y_pred_lassocv = np.expm1(lassocv.predict(X_train))
Y_pred_lassolarscv = np.expm1(lassolarscv.predict(X_train))
Y_pred_elasticnetcv = np.expm1(elasticnetcv.predict(X_train))

# %% [markdown]
# # Tree based modeling

# %%
# XGBoost

#model_xgb = xgb.XGBRegressor(n_estimators=3000, max_depth=2, learning_rate=0.1)
model_xgb = xgb.XGBRegressor(colsample_bytree=0.2, gamma=0.0, 
                             learning_rate=0.05, max_depth=6, 
                             min_child_weight=1.5, n_estimators=7200,
                             reg_alpha=0.9, reg_lambda=0.6,
                             subsample=0.2,seed=42, silent=1)

RMSE(model_xgb,X_train,Y_train)
# Out:
# 0.42856959658825389

# %%
model_xgb.fit(X_train,Y_train)
Y_pred_xgb = np.expm1(model_xgb.predict(X_train))

# %%
# Gradient Boosting
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
RMSE(GBoost,X_train,Y_train)
# Out:
# 0.42689990100825581

# %%
GBoost.fit(X_train,Y_train)
Y_pred_GBoost = np.expm1(GBoost.predict(X_train))

# %%
# Light GBM
LightGB = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

RMSE(LightGB,X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-0f7d113db2b3> in <module>()
#       1 # Light GBM
# ----> 2 LightGB = lgb.LGBMRegressor(objective='regression',num_leaves=5,
#       3                               learning_rate=0.05, n_estimators=720,
#       4                               max_bin = 55, bagging_fraction = 0.8,
#       5                               bagging_freq = 5, feature_fraction = 0.2319,
#
# NameError: name 'lgb' is not defined

# %%
LightGB.fit(X_train,Y_train)
Y_pred_LightGB = np.expm1(LightGB.predict(X_train))

# %% [markdown]
# # Features importance

# %%
nrows = 1
ncols = 2
fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize=(15,15))

names_regressors = [("LightGBM",LightGB),("GBoosting",GBoost)]

nregressors = 0
for row in range(nrows):
    for col in range(ncols):
        name = names_regressors[nregressors][0]
        regressor = names_regressors[nregressors][1]
        indices = np.argsort(regressor.feature_importances_)[::-1][:40]
        g = sns.barplot(y=features[indices][:40],x = regressor.feature_importances_[indices][:40] , orient='h',ax=axes[nregressors])
        g.set_xlabel("Relative importance",fontsize=12)
        g.set_ylabel("Features",fontsize=12)
        g.tick_params(labelsize=9)
        g.set_title(name + " feature importance")
        nregressors += 1

plt.tight_layout()
plt.show()
plt.gcf().clear()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-b97d8b749754> in <module>()
#       3 fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize=(15,15))
#       4
# ----> 5 names_regressors = [("LightGBM",LightGB),("GBoosting",GBoost)]
#       6
#       7 nregressors = 0
#
# NameError: name 'LightGB' is not defined

# %% [markdown]
# # Learning Rate

# %%
def plot_learning_curves(estimators, titles, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 4)):
    """Generate a simple plot of the test and training learning curve"""
    nrows = len(estimators)//2
    ncols = (len(estimators)//nrows)+ (0 if len(estimators) % nrows == 0 else 1)
    plt.figure(1)
    fig, axes = plt.subplots(nrows, ncols, figsize=(10, 10))
    
    n = 0
    for col in range(ncols):
        for row in range(nrows):
            estimator = estimators[n]
            title = titles[n]
            axes[row,col].set_title(title)
            
            if ylim is not None:
                axes[row,col].set_ylim(*ylim)
            
            axes[row,col].set_xlabel("Training examples")
            axes[row,col].set_ylabel("Score")
            
            train_sizes, train_scores, test_scores = learning_curve(estimator,
                    X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes,
                    scoring="neg_mean_squared_error")
    
            train_scores = np.sqrt(-train_scores)
            test_scores = np.sqrt(-test_scores)
    
            train_scores_mean = np.mean(train_scores, axis=1)
            train_scores_std = np.std(train_scores, axis=1)
            test_scores_mean = np.mean(test_scores, axis=1)
            test_scores_std = np.std(test_scores, axis=1)
            axes[row,col].grid()
        
            axes[row,col].fill_between(train_sizes, train_scores_mean - train_scores_std,
                             train_scores_mean + train_scores_std, alpha=0.5,
                     color="r")
            axes[row,col].fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.5, color="g")
            axes[row,col].plot(train_sizes, train_scores_mean, 'o-', color="r",
                     label="Training score")
            axes[row,col].plot(train_sizes, test_scores_mean, 'o-', color="g",
                     label="Cross-validation score")
            axes[row,col].legend(loc="best")
            
            n += 1
    plt.tight_layout()
    plt.show()
    plt.gcf().clear()

    

estimators = [lassocv,lassolarscv,elasticnetcv,GBoost,model_xgb]
titles = ["LassoCV","LassoLarsCV","ElasticNet","Gradient Boosting","Xgboost"]

plot_learning_curves(estimators, titles, X_train, Y_train, cv=3 ,n_jobs=5)
# Out:
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=9.704e-04, previous alpha=1.103e-04, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=5.351e-03, previous alpha=1.753e-04, with an active set of 14 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 40 iterations, alpha=2.996e-03, previous alpha=3.329e-05, with an active set of 11 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.409e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=3.038e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.107e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=3.373e-03, previous alpha=2.538e-05, with an active set of 23 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=2.620e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.107e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.217e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=2.607e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.107e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 31 iterations, alpha=2.507e-03, previous alpha=4.092e-05, with an active set of 20 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=2.918e-02, previous alpha=3.703e-05, with an active set of 10 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=6.524e-03, previous alpha=1.811e-04, with an active set of 13 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=1.108e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=1.108e-03, previous alpha=1.096e-03, with an active set of 9 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=1.174e-03, previous alpha=3.540e-05, with an active set of 20 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=9.171e-04, previous alpha=5.002e-05, with an active set of 10 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 44 iterations, alpha=9.161e-03, previous alpha=2.128e-05, with an active set of 19 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=1.969e-03, previous alpha=1.439e-04, with an active set of 15 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.594e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.855e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=8.935e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=1.609e-03, previous alpha=1.540e-03, with an active set of 8 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 34 iterations, alpha=1.190e-04, previous alpha=4.468e-05, with an active set of 19 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.619e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 17 iterations, alpha=1.553e-03, previous alpha=1.479e-03, with an active set of 8 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 43 iterations, alpha=8.398e-02, previous alpha=1.854e-05, with an active set of 12 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.498e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.007e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.140e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.509e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.409e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 11 iterations, alpha=1.133e-03, previous alpha=1.095e-03, with an active set of 6 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.342e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.217e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.302e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.261e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=3.568e-03, previous alpha=4.992e-05, with an active set of 21 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=4.307e-03, previous alpha=3.962e-03, with an active set of 8 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=1.347e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=1.108e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=2.628e-03, previous alpha=1.029e-04, with an active set of 14 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=1.108e-03, previous alpha=1.096e-03, with an active set of 9 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=8.935e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.594e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.619e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=1.617e-03, previous alpha=8.208e-05, with an active set of 17 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.855e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 17 iterations, alpha=1.553e-03, previous alpha=1.479e-03, with an active set of 8 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.498e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=1.609e-03, previous alpha=1.540e-03, with an active set of 8 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.140e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=1.790e-03, previous alpha=1.126e-04, with an active set of 13 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=2.340e-03, previous alpha=8.784e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 11 iterations, alpha=1.133e-03, previous alpha=1.095e-03, with an active set of 6 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=1.025e-02, previous alpha=5.250e-05, with an active set of 19 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 43 iterations, alpha=8.398e-02, previous alpha=1.854e-05, with an active set of 12 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=1.347e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.980e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=9.650e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=2.628e-03, previous alpha=1.029e-04, with an active set of 14 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.007e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=2.075e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=3.946e-03, previous alpha=3.576e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.473e-06, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.509e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.342e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.302e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.261e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.490e-08
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=2.241e-02, previous alpha=4.282e-05, with an active set of 20 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=4.522e-03, previous alpha=6.943e-05, with an active set of 18 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=4.307e-03, previous alpha=3.962e-03, with an active set of 8 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=9.650e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=2.075e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.473e-06, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=8.302e-04, previous alpha=4.657e-05, with an active set of 21 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 41 iterations, alpha=2.667e-04, previous alpha=1.869e-05, with an active set of 20 regressors.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#
# /home/py/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-140-4367456d7b1b> in <module>()
#      54 titles = ["LassoCV","LassoLarsCV","ElasticNet","Gradient Boosting","Xgboost"]
#      55
# ---> 56 plot_learning_curves(estimators, titles, X_train, Y_train, cv=3 ,n_jobs=5)
#
# <ipython-input-140-4367456d7b1b> in plot_learning_curves(estimators, titles, X, y, ylim, cv, n_jobs, train_sizes)
#      10     for col in range(ncols):
#      11         for row in range(nrows):
# ---> 12             estimator = estimators[n]
#      13             title = titles[n]
#      14             axes[row,col].set_title(title)
#
# IndexError: list index out of range
